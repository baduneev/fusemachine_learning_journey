# %%
import pandas as pd

df = pd.read_csv('RewardsData.csv')

df.head(20)
# Out:
#     User ID  Birthdate           City           State    Zip  \
# 0         1  1/31/1992   Minneapolis          Georgia  55401
# 1         2        NaN   Los Angeles         Colorado  90210
# 2         3  1/11/1990         Merida              AL  97204
# 3         4  4/16/1990  Winston-Salem              NC  27106
# 4         5  3/24/1994  Winston-Salem              NC  27109
# 5         6  10/9/1995              G              AL  85588
# 6         7  9/22/1995            NaN             NaN    NaN
# 7         8        NaN            NaN             NaN    NaN
# 8         9        NaN            NaN             NaN    NaN
# 9        10  7/20/1999  Winston Salem              NC  27106
# 10       11  7/22/2000            NaN             NaN    NaN
# 11       12        NaN            NaN             NaN    NaN
# 12       13        NaN            NaN             NaN    NaN
# 13       14  11/1/2000  Winston-Salem              NC  27106
# ...

# %%
df.isna()
# Out:
#       User ID  Birthdate   City  State    Zip  Available Points  \
# 0       False      False  False  False  False             False
# 1       False       True  False  False  False             False
# 2       False      False  False  False  False             False
# 3       False      False  False  False  False             False
# 4       False      False  False  False  False             False
# ...       ...        ...    ...    ...    ...               ...
# 7247    False       True   True   True   True             False
# 7248    False       True   True   True   True             False
# 7249    False      False   True   True   True             False
# 7250    False       True   True   True   True             False
# 7251    False       True   True   True   True             False
#
#       Total Points Earned  Points Spent  Joined On  Last Seen   Tags
# 0                   False         False      False      False  False
# ...

# %%
missing_value_count = df.isna().sum()
missing_value_count
# Out:
# User ID                   0
# Birthdate              6080
# City                   6922
# State                  6922
# Zip                    6922
# Available Points          0
# Total Points Earned       0
# Points Spent              0
# Joined On                 0
# Last Seen                 0
# Tags                      0
# dtype: int64

# %%
missing_values_percent = missing_value_count/len(df) * 100
missing_values_percent
# Out:
# User ID                 0.000000
# Birthdate              83.838941
# City                   95.449531
# State                  95.449531
# Zip                    95.449531
# Available Points        0.000000
# Total Points Earned     0.000000
# Points Spent            0.000000
# Joined On               0.000000
# Last Seen               0.000000
# Tags                    0.000000
# dtype: float64

# %%
df['Last Seen']
# Out:
# 0       12/16/2021 17:42
# 1        4/13/2022 14:28
# 2        4/21/2021 10:54
# 3        6/30/2022 22:22
# 4       12/30/2020 10:57
#               ...
# 7247     6/30/2022 12:04
# 7248     6/28/2022 22:43
# 7249     6/30/2022 12:48
# 7250     6/30/2022 20:39
# 7251       7/1/2022 2:42
# Name: Last Seen, Length: 7252, dtype: str

# %%
df['Last Seen'] = pd.to_datetime(df['Last Seen'])

# %%
df['Last Seen']
# Out:
# 0      2021-12-16 17:42:00
# 1      2022-04-13 14:28:00
# 2      2021-04-21 10:54:00
# 3      2022-06-30 22:22:00
# 4      2020-12-30 10:57:00
#                ...
# 7247   2022-06-30 12:04:00
# 7248   2022-06-28 22:43:00
# 7249   2022-06-30 12:48:00
# 7250   2022-06-30 20:39:00
# 7251   2022-07-01 02:42:00
# Name: Last Seen, Length: 7252, dtype: datetime64[us]

# %%
df['Last Seen'].max()
# Out:
# Timestamp('2022-07-01 08:36:00')

# %%
df['Last Seen'].min()
# Out:
# Timestamp('2020-10-12 14:38:00')

# %%
df['Last Seen'] = df['Last Seen'].fillna(value=df['Last Seen'].min())

# %%
df_sample = df.dropna()
df_sample
# Out:
#       User ID  Birthdate           City           State    Zip  \
# 0           1  1/31/1992   Minneapolis          Georgia  55401
# 2           3  1/11/1990         Merida              AL  97204
# 3           4  4/16/1990  Winston-Salem              NC  27106
# 4           5  3/24/1994  Winston-Salem              NC  27109
# 5           6  10/9/1995              G              AL  85588
# ...       ...        ...            ...             ...    ...
# 7228     7219  6/12/2004    Lutherville        Maryland  21093
# 7229     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 7236     7227  3/14/2000       Clemmons  North Carolina  27012
# 7239     7230  5/18/1999  Winston Salem  North Carolina  27107
# 7244     7235  6/20/2004       Guaynabo     Puerto Rico    969
#
#       Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                  300                  300             0     9/4/2020 0:15
# ...

# %%
df_sample.isna().sum()
# Out:
# User ID                0
# Birthdate              0
# City                   0
# State                  0
# Zip                    0
# Available Points       0
# Total Points Earned    0
# Points Spent           0
# Joined On              0
# Last Seen              0
# Tags                   0
# dtype: int64

# %%
df_sample = df_sample.drop('Tags',axis=1)
df_sample
# Out:
#       User ID  Birthdate           City           State    Zip  \
# 0           1  1/31/1992   Minneapolis          Georgia  55401
# 2           3  1/11/1990         Merida              AL  97204
# 3           4  4/16/1990  Winston-Salem              NC  27106
# 4           5  3/24/1994  Winston-Salem              NC  27109
# 5           6  10/9/1995              G              AL  85588
# ...       ...        ...            ...             ...    ...
# 7228     7219  6/12/2004    Lutherville        Maryland  21093
# 7229     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 7236     7227  3/14/2000       Clemmons  North Carolina  27012
# 7239     7230  5/18/1999  Winston Salem  North Carolina  27107
# 7244     7235  6/20/2004       Guaynabo     Puerto Rico    969
#
#       Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                  300                  300             0     9/4/2020 0:15
# ...

# %%
df_sample['State'] = df_sample['State'].replace(us_state_abbrev)
# Out:
# 0           Georgia
# 2                AL
# 3                NC
# 4               NaN
# 5               NaN
#            ...
# 7228            NaN
# 7229            NaN
# 7236            NaN
# 7239            NaN
# 7244    Puerto Rico
# Name: State, Length: 172, dtype: str

# %%
df_unique_state = pd.DataFrame(df_unique_state, columns=['State'])

df_unique_state['State'] = df_unique_state['State'].replace(to_replace=['Puerto Rico'],value='PR')

df_unique_state['State'] = df_unique_state['State'].str.strip()

df_unique_state['State'] = df_unique_state['State'].str.title()

df_unique_state['State']
# Out:
# 0                       Al
# 1                       Ct
# 2               California
# 3                 Colorado
# 4              Connecticut
# 5     District Of Columbia
# 6                       Fl
# 7                  Florida
# 8                       Ga
# 9                  Georgia
# 10                Illinois
# 11                Kentucky
# 12                      Ma
# 13                      Md
# 14                      Mn
# 15                Maryland
# 16           Massachusetts
# 17                      Nc
# 18                      Nj
# 19                      Ny
# 20              New Jersey
# 21              New Mexico
# 22                New York
# 23          North Carolina
# 24                      Oh
# 25                    Ohio
# 26                      Pa
# 27            Pennsylvania
# 28                      Pr
# 29                      Sc
# 30                      Tn
# 31                      Tx
# 32               Tennessee
# 33                   Texas
# ...

# %%
us_state_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "Puerto Rico": "PR",
    "District Of Columbia" : "DOC"
}

# %%
state_full_name = {v: k for k, v in us_state_abbrev.items()}

df_sample['State'] = df_sample['State'].replace(state_full_name)

df_sample['State']
# Out:
# 0              Georgia
# 2              Alabama
# 3       North Carolina
# 4       North Carolina
# 5              Alabama
#              ...
# 7228          Maryland
# 7229    North Carolina
# 7236    North Carolina
# 7239    North Carolina
# 7244       Puerto Rico
# Name: State, Length: 172, dtype: str

# %%
df_unique_state['State']
# Out:
# 0      Al
# 1      Ct
# 2      CA
# 3      CO
# 4      CT
# 5     DOC
# 6      Fl
# 7      FL
# 8      Ga
# 9      GA
# 10     IL
# 11     KY
# 12     Ma
# 13     Md
# 14     Mn
# 15     MD
# 16     MA
# 17     Nc
# 18     Nj
# 19     Ny
# 20     NJ
# 21     NM
# 22     NY
# 23     NC
# 24     Oh
# 25     OH
# 26     Pa
# 27     PA
# 28     Pr
# 29     Sc
# 30     Tn
# 31     Tx
# 32     TN
# 33     TX
# 34     Wi
# Name: State, dtype: str

# %%
us_state_abbrev.items()

states_df = pd.DataFrame(list(us_state_abbrev.items()), columns=['State','State_ABBREV'])

states_df
# Out:
#                    State State_ABBREV
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8                Florida           FL
# 9                Georgia           GA
# 10                Hawaii           HI
# 11                 Idaho           ID
# 12              Illinois           IL
# 13               Indiana           IN
# 14                  Iowa           IA
# 15                Kansas           KS
# 16              Kentucky           KY
# 17             Louisiana           LA
# 18                 Maine           ME
# 19              Maryland           MD
# 20         Massachusetts           MA
# 21              Michigan           MI
# 22             Minnesota           MN
# 23           Mississippi           MS
# ...

# %%
list(us_state_abbrev.items())
# Out:
# [('Alabama', 'AL'),
#  ('Alaska', 'AK'),
#  ('Arizona', 'AZ'),
#  ('Arkansas', 'AR'),
#  ('California', 'CA'),
#  ('Colorado', 'CO'),
#  ('Connecticut', 'CT'),
#  ('Delaware', 'DE'),
#  ('Florida', 'FL'),
#  ('Georgia', 'GA'),
#  ('Hawaii', 'HI'),
#  ('Idaho', 'ID'),
#  ('Illinois', 'IL'),
#  ('Indiana', 'IN'),
#  ('Iowa', 'IA'),
#  ('Kansas', 'KS'),
#  ('Kentucky', 'KY'),
#  ('Louisiana', 'LA'),
#  ('Maine', 'ME'),
#  ('Maryland', 'MD'),
#  ('Massachusetts', 'MA'),
#  ('Michigan', 'MI'),
#  ('Minnesota', 'MN'),
#  ('Mississippi', 'MS'),
#  ('Missouri', 'MO'),
#  ('Montana', 'MT'),
#  ('Nebraska', 'NE'),
#  ('Nevada', 'NV'),
#  ('New Hampshire', 'NH'),
#  ('New Jersey', 'NJ'),
#  ('New Mexico', 'NM'),
#  ('New York', 'NY'),
#  ('North Carolina', 'NC'),
#  ('North Dakota', 'ND'),
#  ('Ohio', 'OH'),
#  ('Oklahoma', 'OK'),
#  ('Oregon', 'OR'),
#  ('Pennsylvania', 'PA'),
#  ('Rhode Island', 'RI'),
#  ('South Carolina', 'SC'),
#  ('South Dakota', 'SD'),
#  ('Tennessee', 'TN'),
# ...

# %%
df_sample_merged = pd.merge(df_sample, states_df , on="State", how='left' )

df_sample_merged
# Out:
#      User ID  Birthdate           City           State    Zip  \
# 0          1  1/31/1992   Minneapolis          Georgia  55401
# 1          3  1/11/1990         Merida         Alabama  97204
# 2          4  4/16/1990  Winston-Salem  North Carolina  27106
# 3          5  3/24/1994  Winston-Salem  North Carolina  27109
# 4          6  10/9/1995              G         Alabama  85588
# ..       ...        ...            ...             ...    ...
# 167     7219  6/12/2004    Lutherville        Maryland  21093
# 168     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 169     7227  3/14/2000       Clemmons  North Carolina  27012
# 170     7230  5/18/1999  Winston Salem  North Carolina  27107
# 171     7235  6/20/2004       Guaynabo     Puerto Rico    969
#
#      Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                 300                  300             0     9/4/2020 0:15
# ...

# %%
df_sample_merged.rename(columns={'State_ABBREV':'State_Abbreviation'}, inplace = True)
df_sample_merged
# Out:
#      User ID  Birthdate           City           State    Zip  \
# 0          1  1/31/1992   Minneapolis          Georgia  55401
# 1          3  1/11/1990         Merida         Alabama  97204
# 2          4  4/16/1990  Winston-Salem  North Carolina  27106
# 3          5  3/24/1994  Winston-Salem  North Carolina  27109
# 4          6  10/9/1995              G         Alabama  85588
# ..       ...        ...            ...             ...    ...
# 167     7219  6/12/2004    Lutherville        Maryland  21093
# 168     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 169     7227  3/14/2000       Clemmons  North Carolina  27012
# 170     7230  5/18/1999  Winston Salem  North Carolina  27107
# 171     7235  6/20/2004       Guaynabo     Puerto Rico    969
#
#      Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                 300                  300             0     9/4/2020 0:15
# ...

# %%
state_abbrev_col = df_sample_merged.pop('State_Abbreviation')

df_sample_merged.insert(5, 'State_Abbreviation', state_abbrev_col )

# %%
state_abbrev_col = df_sample_merged.pop('State_Abbreviation')

df_sample_merged.insert(4, 'State_Abbreviation', state_abbrev_col ) 

df_sample_merged
# Out:
#      User ID  Birthdate           City           State State_Abbreviation  \
# 0          1  1/31/1992   Minneapolis          Georgia                 GA
# 1          3  1/11/1990         Merida         Alabama                 AL
# 2          4  4/16/1990  Winston-Salem  North Carolina                 NC
# 3          5  3/24/1994  Winston-Salem  North Carolina                 NC
# 4          6  10/9/1995              G         Alabama                 AL
# ..       ...        ...            ...             ...                ...
# 167     7219  6/12/2004    Lutherville        Maryland                 MD
# 168     7220   8/7/1999  Winston-Salem  North Carolina                 NC
# 169     7227  3/14/2000       Clemmons  North Carolina                 NC
# 170     7230  5/18/1999  Winston Salem  North Carolina                 NC
# 171     7235  6/20/2004       Guaynabo     Puerto Rico                 PR
#
#        Zip  Available Points  Total Points Earned  Points Spent  \
# ...

# %%
zip_unique_values = sorted(df_sample_merged['Zip'].unique())

zip_unique_values
# Out:
# ['10538',
#  '11768',
#  '11787',
#  '13026',
#  '13078',
#  '13492',
#  '13753',
#  '14530',
#  '15217',
#  '19352',
#  '19355',
#  '19382',
#  '1945',
#  '2030',
#  '2067',
#  '20814',
#  '21093',
#  '22213',
#  '2332',
#  '2478',
#  '2493',
#  '2532',
#  '2653',
#  '27012',
#  '27013',
#  '27051',
#  '27101',
#  '27103',
#  '27104',
#  '27106',
#  '27107',
#  '27109',
#  '27127',
#  '27360',
#  '27406',
#  '27410',
#  '27516',
#  '27707-1634',
#  '28078',
#  '28079',
#  '28097',
#  '28115',
#  '28117',
#  '28173',
#  '28205',
#  '28209',
#  '28216',
#  '28262',
#  '28269',
#  '28277',
#  '28462',
#  '28655',
#  '29204',
#  '29466',
#  '30165',
#  '30273',
#  '30311',
#  '30338',
#  '32174',
#  '32223',
#  '32608',
#  '33157',
#  '33410',
#  '33596',
#  '33908',
#  '37204',
#  '37205',
#  '38112',
#  '40222',
#  '45174',
#  '45419',
#  '53217',
#  '55401',
#  '55439',
#  '60048',
#  '60085',
#  '60515',
#  '6067',
#  '6880',
#  '69694',
#  '7481',
#  '75205',
#  '75230',
# ...

# %%
# truncating zip code down to five
df_sample['Zip'] = df_sample['Zip'].str[:5]

# %%
zip_bool_index = df_sample['Zip'].str.len() == 5

zip_bool_index
# Out:
# 0        True
# 2        True
# 3        True
# 4        True
# 5        True
#         ...
# 7228     True
# 7229     True
# 7236     True
# 7239     True
# 7244    False
# Name: Zip, Length: 172, dtype: bool

# %%
df_sample = df_sample[zip_bool_index]

# %%
df_sample
# Out:
#       User ID  Birthdate           City           State    Zip  \
# 0           1  1/31/1992   Minneapolis          Georgia  55401
# 2           3  1/11/1990         Merida         Alabama  97204
# 3           4  4/16/1990  Winston-Salem  North Carolina  27106
# 4           5  3/24/1994  Winston-Salem  North Carolina  27109
# 5           6  10/9/1995              G         Alabama  85588
# ...       ...        ...            ...             ...    ...
# 7227     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 7228     7219  6/12/2004    Lutherville        Maryland  21093
# 7229     7220   8/7/1999  Winston-Salem  North Carolina  27106
# 7236     7227  3/14/2000       Clemmons  North Carolina  27012
# 7239     7230  5/18/1999  Winston Salem  North Carolina  27107
#
#       Available Points  Total Points Earned  Points Spent         Joined On  \
# 0                  300                  300             0     9/4/2020 0:15
# ...
